# %%
raw_token = "" # @param {type: "string"}
version = "reflex-0.0.2" # @param {type: "string"}
is_prerelease = True # @param {type: "boolean"}

# %%
# !apt install python3.10-venv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   python3-pip-whl python3-setuptools-whl
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 2,473 kB of archives.
# After this operation, 2,884 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.4 [1,680 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-setuptools-whl all 59.6.0-1.2ubuntu0.22.04.1 [788 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.3 [5,716 B]
# Fetched 2,473 kB in 3s (951 kB/s)
# Selecting previously unselected package python3-pip-whl.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../python3-pip-whl_22.0.2+dfsg-1ubuntu0.4_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.4) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../python3-setuptools-whl_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../python3.10-venv_3.10.12-1~22.04.3_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.3) ...
# Setting up python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up python3.10-venv (3.10.12-1~22.04.3) ...

# %%
# !sudo mkdir -p -m 755 /etc/apt/keyrings && wget -qO- https://cli.github.com/packages/githubcli-archive-keyring.gpg | sudo tee /etc/apt/keyrings/githubcli-archive-keyring.gpg > /dev/null \
&& sudo chmod go+r /etc/apt/keyrings/githubcli-archive-keyring.gpg \
&& echo "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/githubcli-archive-keyring.gpg] https://cli.github.com/packages stable main" | sudo tee /etc/apt/sources.list.d/github-cli.list > /dev/null \
&& sudo apt update \
&& sudo apt install gh -y
# !gh version
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [814 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:7 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:9 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [2,259 kB]
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,035 kB]
# Hit:14 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,339 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,753 kB]
# Fetched 9,438 kB in 4s (2,621 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 45 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   gh
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 13.5 MB of archives.
# After this operation, 49.5 MB of additional disk space will be used.
# Get:1 https://cli.github.com/packages stable/main amd64 gh amd64 2.48.0 [13.5 MB]
# Fetched 13.5 MB in 1s (23.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package gh.
# (Reading database ... 121767 files and directories currently installed.)
# Preparing to unpack .../archives/gh_2.48.0_amd64.deb ...
# Unpacking gh (2.48.0) ...
# Setting up gh (2.48.0) ...
# Processing triggers for man-db (2.10.2-1) ...
# gh version 2.48.0 (2024-04-17)
# https://github.com/cli/cli/releases/tag/v2.48.0

# %%
# !echo {raw_token} > /content/pat.txt

# %%
# !gh auth login --hostname github.com -p https --with-token  < /content/pat.txt

# %%
# !gh auth status
# Out:
# github.com
#   ✓ Logged in to github.com account ryugibo (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: github_pat_11AB4PWOA0lpljujJOobbj_***********************************************************

# %%
# !rm /content/pat.txt

# %%
# !gh repo clone pal-ette/iNotePal
# Out:
# Cloning into 'iNotePal'...
# remote: Enumerating objects: 877, done.
# remote: Counting objects: 100% (280/280), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 877 (delta 163), reused 202 (delta 128), pack-reused 597
# Receiving objects: 100% (877/877), 4.17 MiB | 8.09 MiB/s, done.
# Resolving deltas: 100% (413/413), done.

# %%
# %cd iNotePal/app
# Out:
# /content/iNotePal/app

# %%
# !./deploy/init.sh
# Out:
# ./deploy/init.sh: 3: asdf: not found
# Collecting bcrypt==4.1.2
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 KB 6.9 MB/s eta 0:00:00
# Collecting openai==1.20.0
#   Downloading openai-1.20.0-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 KB 8.6 MB/s eta 0:00:00
# Collecting PyJWT==2.8.0
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Collecting python-dotenv==1.0.1
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting reflex==0.4.9
#   Downloading reflex-0.4.9-py3-none-any.whl (780 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.5/780.5 KB 11.5 MB/s eta 0:00:00
# Collecting scikit-learn==1.2.2
#   Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 18.4 MB/s eta 0:00:00
# Collecting supabase==2.4.3
#   Downloading supabase-2.4.3-py3-none-any.whl (15 kB)
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 2.3 MB/s eta 0:00:00
# Collecting reflex-calendar==0.0.4
#   Downloading reflex_calendar-0.0.4-py3-none-any.whl (5.8 kB)
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 KB 8.5 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting tqdm>4
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 KB 7.7 MB/s eta 0:00:00
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 5.9 MB/s eta 0:00:00
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 KB 28.4 MB/s eta 0:00:00
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting typing-extensions<5,>=4.7
#   Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Collecting sqlmodel<0.1,>=0.0.14
#   Downloading sqlmodel-0.0.16-py3-none-any.whl (26 kB)
# Collecting packaging<25.0,>=23.1
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 KB 6.0 MB/s eta 0:00:00
# Collecting build<2.0,>=1.0.3
#   Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Collecting dill<0.4,>=0.3.8
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 KB 10.7 MB/s eta 0:00:00
# Collecting rich<14.0,>=13.0.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 KB 19.1 MB/s eta 0:00:00
# Collecting jinja2<4.0,>=3.1.2
#   Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 KB 12.8 MB/s eta 0:00:00
# Collecting platformdirs<5.0,>=3.10.0
#   Downloading platformdirs-4.2.1-py3-none-any.whl (17 kB)
# Collecting watchfiles<1.0,>=0.19.0
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.6 MB/s eta 0:00:00
# Collecting python-engineio!=4.6.0
#   Downloading python_engineio-4.9.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 6.3 MB/s eta 0:00:00
# Collecting python-socketio<6.0,>=5.7.0
#   Downloading python_socketio-5.11.2-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 KB 8.3 MB/s eta 0:00:00
# Collecting wrapt<2.0,>=1.11.0
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 KB 8.8 MB/s eta 0:00:00
# Collecting tomlkit<1.0,>=0.12.4
#   Downloading tomlkit-0.12.4-py3-none-any.whl (37 kB)
# Collecting python-multipart<0.1,>=0.0.5
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting twine<6.0,>=4.0.0
#   Downloading twine-5.0.0-py3-none-any.whl (37 kB)
# Collecting watchdog<5.0,>=2.3.1
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 KB 10.0 MB/s eta 0:00:00
# Collecting psutil<6.0,>=5.9.4
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 KB 25.2 MB/s eta 0:00:00
# Collecting redis<6.0,>=4.3.5
#   Downloading redis-5.0.4-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.0/252.0 KB 22.6 MB/s eta 0:00:00
# Collecting charset-normalizer<4.0,>=3.3.2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 KB 16.2 MB/s eta 0:00:00
# Collecting alembic<2.0,>=1.11.1
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 KB 23.0 MB/s eta 0:00:00
# Collecting fastapi<1.0,>=0.96.0
#   Downloading fastapi-0.110.2-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 KB 10.4 MB/s eta 0:00:00
# Collecting wheel<1.0,>=0.42.0
#   Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# Collecting setuptools<70.0,>=69.1.1
#   Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# Collecting reflex-hosting-cli<2.0,>=0.1.2
#   Downloading reflex_hosting_cli-0.1.13-py3-none-any.whl (32 kB)
# Collecting gunicorn<22.0,>=20.1.0
#   Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 KB 9.3 MB/s eta 0:00:00
# Collecting starlette-admin<1.0,>=0.11.0
#   Downloading starlette_admin-0.13.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 76.4 MB/s eta 0:00:00
# Collecting typer<1.0,>=0.4.2
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 KB 5.0 MB/s eta 0:00:00
# Collecting uvicorn<0.21.0,>=0.20.0
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 6.5 MB/s eta 0:00:00
# Collecting scipy>=1.3.2
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 19.6 MB/s eta 0:00:00
# Collecting numpy>=1.17.3
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 65.1 MB/s eta 0:00:00
# Collecting joblib>=1.1.1
#   Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 KB 27.9 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Collecting gotrue<3.0,>=1.3
#   Downloading gotrue-2.4.2-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 KB 4.6 MB/s eta 0:00:00
# Collecting realtime<2.0.0,>=1.0.0
#   Downloading realtime-1.0.4-py3-none-any.whl (8.9 kB)
# Collecting supafunc<0.5.0,>=0.3.1
#   Downloading supafunc-0.4.5-py3-none-any.whl (6.1 kB)
# Collecting postgrest<0.17.0,>=0.14
#   Downloading postgrest-0.16.3-py3-none-any.whl (20 kB)
# Collecting storage3<0.8.0,>=0.5.3
#   Downloading storage3-0.7.4-py3-none-any.whl (15 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 6.2 MB/s eta 0:00:00
# Collecting flatbuffers>=23.5.26
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 KB 32.7 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 KB 14.0 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 KB 8.0 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Collecting ml-dtypes~=0.2.0
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.6 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 35.5 MB/s eta 0:00:00
# Collecting tensorboard<2.16,>=2.15
#   Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 34.2 MB/s eta 0:00:00
# Collecting wrapt<2.0,>=1.11.0
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 9.3 MB/s eta 0:00:00
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 80.1 MB/s eta 0:00:00
# Collecting keras<2.16,>=2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 57.3 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.36.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 74.6 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.62.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 81.2 MB/s eta 0:00:00
# Collecting six>=1.12.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 KB 1.9 MB/s eta 0:00:00
# Collecting SQLAlchemy>=1.3.0
#   Downloading SQLAlchemy-2.0.29-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.8 MB/s eta 0:00:00
# Collecting Mako
#   Downloading Mako-1.3.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 KB 10.0 MB/s eta 0:00:00
# Collecting idna>=2.8
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 KB 7.5 MB/s eta 0:00:00
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting starlette<0.38.0,>=0.37.2
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 KB 8.2 MB/s eta 0:00:00
# Collecting certifi
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 KB 18.1 MB/s eta 0:00:00
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 8.4 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 7.0 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting deprecation<3.0.0,>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting strenum<0.5.0,>=0.4.9
#   Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Collecting pydantic-core==2.18.2
#   Downloading pydantic_core-2.18.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 39.0 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting simple-websocket>=0.10.0
#   Downloading simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Collecting bidict>=0.21.0
#   Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Collecting websockets<13,>=11
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 KB 15.1 MB/s eta 0:00:00
# Collecting python-dateutil<3.0.0,>=2.8.1
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 KB 23.4 MB/s eta 0:00:00
# Collecting async-timeout>=4.0.3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting pipdeptree<2.17.0,>=2.13.1
#   Downloading pipdeptree-2.16.2-py3-none-any.whl (27 kB)
# Collecting tabulate<0.10.0,>=0.9.0
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 10.4 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 66.3 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 82.2 MB/s eta 0:00:00
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 KB 7.4 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 KB 12.6 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<2,>=0.5
#   Downloading google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.2/189.2 KB 20.0 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.0.2-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 KB 24.0 MB/s eta 0:00:00
# Collecting keyring>=15.1
#   Downloading keyring-25.1.0-py3-none-any.whl (37 kB)
# Collecting rfc3986>=1.4.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 14.1 MB/s eta 0:00:00
# Collecting requests-toolbelt!=0.9.0,>=0.8.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 6.0 MB/s eta 0:00:00
# Collecting readme-renderer>=35.0
#   Downloading readme_renderer-43.0-py3-none-any.whl (13 kB)
# Collecting pkginfo>=1.8.1
#   Downloading pkginfo-1.10.0-py3-none-any.whl (30 kB)
# Collecting importlib-metadata>=3.6
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting click>=8.0.0
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 KB 9.6 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 KB 15.4 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Collecting jaraco.context
#   Downloading jaraco.context-5.3.0-py3-none-any.whl (6.5 kB)
# Collecting jaraco.functools
#   Downloading jaraco.functools-4.0.1-py3-none-any.whl (9.8 kB)
# Collecting SecretStorage>=3.2
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 KB 5.5 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting pip>=23.1.2
#   Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 75.5 MB/s eta 0:00:00
# Collecting nh3>=0.2.14
#   Downloading nh3-0.2.17-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (777 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.1/777.1 KB 51.1 MB/s eta 0:00:00
# Collecting docutils>=0.13.1
#   Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 KB 40.9 MB/s eta 0:00:00
# Collecting wsproto
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 KB 47.3 MB/s eta 0:00:00
# Collecting pyasn1<0.7.0,>=0.4.6
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 KB 11.2 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 KB 15.5 MB/s eta 0:00:00
# Collecting cryptography>=2.0
#   Downloading cryptography-42.0.5-cp39-abi3-manylinux_2_28_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 89.7 MB/s eta 0:00:00
# Collecting more-itertools
#   Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 6.0 MB/s eta 0:00:00
# Collecting backports.tarfile
#   Downloading backports.tarfile-1.1.1-py3-none-any.whl (29 kB)
# Collecting cffi>=1.12
#   Using cached cffi-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# Collecting pycparser
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: strenum, nh3, libclang, flatbuffers, zipp, wrapt, wheel, websockets, watchdog, urllib3, typing-extensions, tqdm, tomlkit, tomli, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, tabulate, sniffio, six, shellingham, setuptools, rfc3986, python-multipart, python-dotenv, PyJWT, pygments, pycparser, pyasn1, psutil, protobuf, platformdirs, pkginfo, pip, packaging, oauthlib, numpy, more-itertools, mdurl, MarkupSafe, markdown, keras, joblib, jeepney, idna, h11, grpcio, greenlet, gast, exceptiongroup, docutils, distro, dill, click, charset-normalizer, certifi, cachetools, bidict, bcrypt, backports.tarfile, async-timeout, annotated-types, absl-py, wsproto, werkzeug, uvicorn, SQLAlchemy, scipy, rsa, requests, redis, readme-renderer, python-dateutil, pyproject_hooks, pydantic-core, pyasn1-modules, pipdeptree, opt-einsum, ml-dtypes, markdown-it-py, Mako, jinja2, jaraco.functools, jaraco.context, jaraco.classes, importlib-metadata, httpcore, h5py, gunicorn, google-pasta, deprecation, cffi, astunparse, anyio, watchfiles, starlette, simple-websocket, scikit-learn, rich, requests-toolbelt, requests-oauthlib, realtime, pydantic, httpx, google-auth, cryptography, build, alembic, typer, supafunc, storage3, starlette-admin, sqlmodel, SecretStorage, python-engineio, postgrest, openai, gotrue, google-auth-oauthlib, fastapi, tensorboard, supabase, reflex-hosting-cli, python-socketio, keyring, twine, tensorflow, reflex, reflex-calendar
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.6.0
#     Uninstalling setuptools-59.6.0:
#       Successfully uninstalled setuptools-59.6.0
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
# Successfully installed Mako-1.3.3 MarkupSafe-2.1.5 PyJWT-2.8.0 SQLAlchemy-2.0.29 SecretStorage-3.3.3 absl-py-2.1.0 alembic-1.13.1 annotated-types-0.6.0 anyio-4.3.0 astunparse-1.6.3 async-timeout-4.0.3 backports.tarfile-1.1.1 bcrypt-4.1.2 bidict-0.23.1 build-1.2.1 cachetools-5.3.3 certifi-2024.2.2 cffi-1.16.0 charset-normalizer-3.3.2 click-8.1.7 cryptography-42.0.5 deprecation-2.1.0 dill-0.3.8 distro-1.9.0 docutils-0.21.2 exceptiongroup-1.2.1 fastapi-0.110.2 flatbuffers-24.3.25 gast-0.5.4 google-auth-2.29.0 google-auth-oauthlib-1.2.0 google-pasta-0.2.0 gotrue-2.4.2 greenlet-3.0.3 grpcio-1.62.2 gunicorn-21.2.0 h11-0.14.0 h5py-3.11.0 httpcore-1.0.5 httpx-0.27.0 idna-3.7 importlib-metadata-7.1.0 jaraco.classes-3.4.0 jaraco.context-5.3.0 jaraco.functools-4.0.1 jeepney-0.8.0 jinja2-3.1.3 joblib-1.4.0 keras-2.15.0 keyring-25.1.0 libclang-18.1.1 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.2.0 more-itertools-10.2.0 nh3-0.2.17 numpy-1.26.4 oauthlib-3.2.2 openai-1.20.0 opt-einsum-3.3.0 packaging-24.0 pip-24.0 pipdeptree-2.16.2 pkginfo-1.10.0 platformdirs-4.2.1 postgrest-0.16.3 protobuf-4.25.3 psutil-5.9.8 pyasn1-0.6.0 pyasn1-modules-0.4.0 pycparser-2.22 pydantic-2.7.1 pydantic-core-2.18.2 pygments-2.17.2 pyproject_hooks-1.0.0 python-dateutil-2.9.0.post0 python-dotenv-1.0.1 python-engineio-4.9.0 python-multipart-0.0.9 python-socketio-5.11.2 readme-renderer-43.0 realtime-1.0.4 redis-5.0.4 reflex-0.4.9 reflex-calendar-0.0.4 reflex-hosting-cli-0.1.13 requests-2.31.0 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 rfc3986-2.0.0 rich-13.7.1 rsa-4.9 scikit-learn-1.2.2 scipy-1.13.0 setuptools-69.5.1 shellingham-1.5.4 simple-websocket-1.0.0 six-1.16.0 sniffio-1.3.1 sqlmodel-0.0.16 starlette-0.37.2 starlette-admin-0.13.2 storage3-0.7.4 strenum-0.4.15 supabase-2.4.3 supafunc-0.4.5 tabulate-0.9.0 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-io-gcs-filesystem-0.36.0 termcolor-2.4.0 threadpoolctl-3.4.0 tomli-2.0.1 tomlkit-0.12.4 tqdm-4.66.2 twine-5.0.0 typer-0.12.3 typing-extensions-4.11.0 urllib3-2.2.1 uvicorn-0.20.0 watchdog-4.0.0 watchfiles-0.21.0 websockets-12.0 werkzeug-3.0.2 wheel-0.43.0 wrapt-1.14.1 wsproto-1.2.0 zipp-3.18.1

# %%
# !./deploy/build.sh
# Out:
# ───────────────────────────────────────── Initializing app ─────────────────────────────────────────
# [04:07:09] Prior to reflex 0.4.0, rx.* components are based on Chakra UI. They are now ]8;id=590732;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=926095;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#            based on Radix UI. To stick to Chakra UI, use rx.chakra.*.
#                                                                                        ]8;id=814290;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=325388;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#            Run `reflex script keep-chakra` to automatically update your app.           ]8;id=678842;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=554696;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#                                                                                        ]8;id=774816;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=795243;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#            For more details, please see                                                ]8;id=595473;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=45167;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#            https://reflex.dev/blog/2024-02-16-reflex-v0.4.0/
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
#
# [04:07:16] Initializing the web directory.                                             ]8;id=649087;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=958319;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
# Success: Initialized app
# ──────────────────────── Compiling production app and preparing for export. ────────────────────────
# Compiling: ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 15/15 0:00:01
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolved, downloaded and extracted [570]
# ⠙ Installing base frontend packages  Resolved, downloaded and extracted [570]
# ⠹ Installing base frontend packages  Resolved, downloaded and extracted [570]
# ⠸ Installing base frontend packages  Resolved, downloaded and extracted [570]
# ⠼ Installing base frontend packages  140 packages installed [6.01s]
# ⠼ Installing base frontend packages  140 packages installed [6.01s]
#
# ⠋ Installing tailwind  Resolving dependencies
# ⠙ Installing tailwind  Resolving dependencies
# ⠹ Installing tailwind  Resolving dependencies
# ⠸ Installing tailwind  Resolving dependencies
# ⠼ Installing tailwind  Resolving dependencies
# ⠴ Installing tailwind  Resolving dependencies
# ⠦ Installing tailwind  Resolving dependencies
# ⠧ Installing tailwind  Resolved, downloaded and extracted [274]
# ⠇ Installing tailwind  79 packages installed [726.00ms]
#
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolved, downloaded and extracted [848]
# ⠼ Installing frontend packages from config and components  Resolved, downloaded and extracted [848]
# ⠴ Installing frontend packages from config and components  Resolved, downloaded and extracted [848]
# ⠦ Installing frontend packages from config and components  Resolved, downloaded and extracted [848]
# ⠧ Installing frontend packages from config and components  Resolved, downloaded and extracted [848]
# ⠇ Installing frontend packages from config and components  214 packages installed [7.11s]
#
# Creating Production Build:  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 9/9 0:01:19
# Zipping Frontend: ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 27/27 0:00:00
# Zipping Backend: ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 23/23 0:00:00

# %%
# !ls -al | grep .zip
# Out:
# -rw-r--r--  1 root root  13427 Apr 24 04:08 backend.zip
# -rw-r--r--  1 root root 582636 Apr 24 04:08 frontend.zip

# %%
# %cd /content/
# !gh repo clone pal-ette/iNotePal iNotePal-pages -- --branch gh-pages
# %cd iNotePal-pages
# !ls | xargs rm -rf
# !ls -al
# !unzip /content/iNotePal/app/frontend.zip
# !git add . & git commit -m "Deploy frontend" & git push -u origin gh-pages

# %%
release_options = " ".join([
    version,
    "--prerelease" if is_prerelease else "",
])
release_options
# Out:
# 'reflex-0.0.2 --prerelease'

# %%
# !gh release create {release_options} --generate-notes /content/iNotePal/app/*.zip
# Out:
# https://github.com/pal-ette/iNotePal/releases/tag/reflex-0.0.2
