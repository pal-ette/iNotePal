# %%
raw_token = "" # @param {type: "string"}
version = "reflex-0.1.7" # @param {type: "string"}
is_prerelease = False # @param {type: "boolean"}

# %%
# !apt install python3.10-venv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   python3-pip-whl python3-setuptools-whl
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 2,473 kB of archives.
# After this operation, 2,884 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.4 [1,680 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-setuptools-whl all 59.6.0-1.2ubuntu0.22.04.1 [788 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.3 [5,716 B]
# Fetched 2,473 kB in 1s (2,918 kB/s)
# Selecting previously unselected package python3-pip-whl.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../python3-pip-whl_22.0.2+dfsg-1ubuntu0.4_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.4) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../python3-setuptools-whl_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../python3.10-venv_3.10.12-1~22.04.3_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.3) ...
# Setting up python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up python3.10-venv (3.10.12-1~22.04.3) ...

# %%
# !sudo mkdir -p -m 755 /etc/apt/keyrings && wget -qO- https://cli.github.com/packages/githubcli-archive-keyring.gpg | sudo tee /etc/apt/keyrings/githubcli-archive-keyring.gpg > /dev/null \
&& sudo chmod go+r /etc/apt/keyrings/githubcli-archive-keyring.gpg \
&& echo "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/githubcli-archive-keyring.gpg] https://cli.github.com/packages stable main" | sudo tee /etc/apt/sources.list.d/github-cli.list > /dev/null \
&& sudo apt update \
&& sudo apt install gh -y
# !gh version
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [344 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [830 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,069 kB]
# Hit:11 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,082 kB]
# Hit:14 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,374 kB]
# Hit:16 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,798 kB]
# Fetched 7,500 kB in 2s (3,829 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 51 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   gh
# 0 upgraded, 1 newly installed, 0 to remove and 51 not upgraded.
# Need to get 13.6 MB of archives.
# After this operation, 50.0 MB of additional disk space will be used.
# Get:1 https://cli.github.com/packages stable/main amd64 gh amd64 2.49.1 [13.6 MB]
# Fetched 13.6 MB in 0s (43.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package gh.
# (Reading database ... 121933 files and directories currently installed.)
# Preparing to unpack .../archives/gh_2.49.1_amd64.deb ...
# Unpacking gh (2.49.1) ...
# Setting up gh (2.49.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# gh version 2.49.1 (2024-05-08)
# https://github.com/cli/cli/releases/tag/v2.49.1

# %%
# !echo {raw_token} > /content/pat.txt

# %%
# !gh auth login --hostname github.com -p https --with-token  < /content/pat.txt

# %%
# !gh auth status
# Out:
# github.com
#   ✓ Logged in to github.com account ryugibo (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: github_pat_11AB4PWOA0lpljujJOobbj_***********************************************************

# %%
# !rm /content/pat.txt

# %%
# %cd /content
# Out:
# /content

# %%
# !rm -rf iNotePal

# %%
# !gh repo clone pal-ette/iNotePal
# Out:
# Cloning into 'iNotePal'...
# remote: Enumerating objects: 2464, done.
# remote: Counting objects: 100% (936/936), done.
# remote: Compressing objects: 100% (273/273), done.
# remote: Total 2464 (delta 644), reused 842 (delta 592), pack-reused 1528
# Receiving objects: 100% (2464/2464), 16.56 MiB | 20.09 MiB/s, done.
# Resolving deltas: 100% (1504/1504), done.

# %%
# %cd iNotePal/app
# Out:
# /content/iNotePal/app

# %%
# !./deploy/init_ubuntu.sh
# Out:
# ./deploy/init_ubuntu.sh: 3: asdf: not found
# Collecting absl-py==2.1.0
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 KB 4.1 MB/s eta 0:00:00
# Collecting alembic==1.13.1
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 KB 11.2 MB/s eta 0:00:00
# Collecting annotated-types==0.6.0
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting anyio==4.3.0
#   Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 KB 12.5 MB/s eta 0:00:00
# Collecting astunparse==1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting async-timeout==4.0.3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting backports.tarfile==1.1.1
#   Downloading backports.tarfile-1.1.1-py3-none-any.whl (29 kB)
# Collecting bcrypt==4.1.2
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 KB 14.9 MB/s eta 0:00:00
# Collecting bidict==0.23.1
#   Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Collecting build==1.2.1
#   Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Collecting cachetools==5.3.3
#   Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Collecting certifi==2024.2.2
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 KB 11.3 MB/s eta 0:00:00
# Collecting cffi==1.16.0
#   Using cached cffi-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# Collecting charset-normalizer==3.3.2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 KB 11.4 MB/s eta 0:00:00
# Collecting click==8.1.7
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 KB 13.2 MB/s eta 0:00:00
# Collecting cryptography==42.0.7
#   Downloading cryptography-42.0.7-cp39-abi3-manylinux_2_28_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 26.0 MB/s eta 0:00:00
# Collecting deprecation==2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting dill==0.3.8
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 KB 18.4 MB/s eta 0:00:00
# Collecting distro==1.9.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting docutils==0.21.2
#   Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 KB 30.7 MB/s eta 0:00:00
# Collecting exceptiongroup==1.2.1
#   Downloading exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Collecting fastapi==0.110.3
#   Downloading fastapi-0.110.3-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 KB 14.9 MB/s eta 0:00:00
# Collecting filelock==3.14.0
#   Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Collecting flatbuffers==24.3.25
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting fsspec==2024.3.1
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 KB 26.7 MB/s eta 0:00:00
# Collecting gast==0.5.4
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-auth==2.29.0
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.2/189.2 KB 26.8 MB/s eta 0:00:00
# Collecting google-auth-oauthlib==1.2.0
#   Downloading google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting google-pasta==0.2.0
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 9.6 MB/s eta 0:00:00
# Collecting gotrue==2.4.2
#   Downloading gotrue-2.4.2-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 KB 6.4 MB/s eta 0:00:00
# Collecting greenlet==3.0.3
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 KB 21.3 MB/s eta 0:00:00
# Collecting grpcio==1.63.0
#   Downloading grpcio-1.63.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 41.4 MB/s eta 0:00:00
# Collecting gunicorn==21.2.0
#   Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 KB 12.8 MB/s eta 0:00:00
# Collecting h11==0.14.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 9.9 MB/s eta 0:00:00
# Collecting h5py==3.11.0
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 74.7 MB/s eta 0:00:00
# Collecting httpcore==1.0.5
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 12.5 MB/s eta 0:00:00
# Collecting httpx==0.27.0
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 KB 12.2 MB/s eta 0:00:00
# Collecting huggingface-hub==0.23.0
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 KB 47.7 MB/s eta 0:00:00
# Collecting idna==3.7
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 KB 9.0 MB/s eta 0:00:00
# Collecting importlib_metadata==7.1.0
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Collecting install-jdk==1.1.0
#   Downloading install_jdk-1.1.0-py3-none-any.whl (15 kB)
# Collecting jaraco.classes==3.4.0
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Collecting jaraco.context==5.3.0
#   Downloading jaraco.context-5.3.0-py3-none-any.whl (6.5 kB)
# Collecting jaraco.functools==4.0.1
#   Downloading jaraco.functools-4.0.1-py3-none-any.whl (9.8 kB)
# Collecting jeepney==0.8.0
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 KB 7.6 MB/s eta 0:00:00
# Collecting Jinja2==3.1.4
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 KB 20.5 MB/s eta 0:00:00
# Collecting joblib==1.4.2
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 KB 34.4 MB/s eta 0:00:00
# Collecting JPype1==1.5.0
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 KB 53.3 MB/s eta 0:00:00
# Collecting keras==2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 65.1 MB/s eta 0:00:00
# Collecting keyring==25.2.0
#   Downloading keyring-25.2.0-py3-none-any.whl (38 kB)
# Collecting konlpy==0.6.0
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 62.6 MB/s eta 0:00:00
# Collecting libclang==18.1.1
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 57.1 MB/s eta 0:00:00
# Collecting lxml==5.2.1
#   Downloading lxml-5.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 71.5 MB/s eta 0:00:00
# Collecting Mako==1.3.3
#   Downloading Mako-1.3.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 KB 10.5 MB/s eta 0:00:00
# Collecting Markdown==3.6
#   Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 KB 14.4 MB/s eta 0:00:00
# Collecting markdown-it-py==3.0.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 11.9 MB/s eta 0:00:00
# Collecting MarkupSafe==2.1.5
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mdurl==0.1.2
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting ml-dtypes==0.2.0
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.3 MB/s eta 0:00:00
# Collecting more-itertools==10.2.0
#   Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 6.8 MB/s eta 0:00:00
# Collecting mpmath==1.3.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 42.0 MB/s eta 0:00:00
# Collecting networkx==3.3
#   Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.6 MB/s eta 0:00:00
# Collecting nh3==0.2.17
#   Downloading nh3-0.2.17-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (777 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.1/777.1 KB 46.6 MB/s eta 0:00:00
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 20.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvjitlink-cu12==12.4.127
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Collecting nvidia-nvtx-cu12==12.1.105
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting oauthlib==3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 KB 23.2 MB/s eta 0:00:00
# Collecting openai==1.20.0
#   Downloading openai-1.20.0-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 KB 35.6 MB/s eta 0:00:00
# Collecting opt-einsum==3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 KB 11.4 MB/s eta 0:00:00
# Collecting packaging==24.0
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 KB 9.0 MB/s eta 0:00:00
# Collecting pillow==10.3.0
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 84.6 MB/s eta 0:00:00
# Collecting pipdeptree==2.16.2
#   Downloading pipdeptree-2.16.2-py3-none-any.whl (27 kB)
# Collecting pkginfo==1.10.0
#   Downloading pkginfo-1.10.0-py3-none-any.whl (30 kB)
# Collecting platformdirs==4.2.1
#   Downloading platformdirs-4.2.1-py3-none-any.whl (17 kB)
# Collecting postgrest==0.16.4
#   Downloading postgrest-0.16.4-py3-none-any.whl (20 kB)
# Collecting protobuf==4.25.3
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 KB 39.4 MB/s eta 0:00:00
# Collecting psutil==5.9.8
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 KB 38.4 MB/s eta 0:00:00
# Collecting pyasn1==0.6.0
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 KB 13.6 MB/s eta 0:00:00
# Collecting pyasn1_modules==0.4.0
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 KB 23.6 MB/s eta 0:00:00
# Collecting pycparser==2.22
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Collecting pydantic==2.7.1
#   Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 KB 49.0 MB/s eta 0:00:00
# Collecting pydantic_core==2.18.2
#   Downloading pydantic_core-2.18.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 55.7 MB/s eta 0:00:00
# Collecting Pygments==2.18.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 57.4 MB/s eta 0:00:00
# Collecting PyJWT==2.8.0
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Collecting pyproject_hooks==1.1.0
#   Downloading pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Collecting python-dateutil==2.9.0.post0
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 KB 25.4 MB/s eta 0:00:00
# Collecting python-dotenv==1.0.1
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting python-engineio==4.9.0
#   Downloading python_engineio-4.9.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 5.8 MB/s eta 0:00:00
# Collecting python-multipart==0.0.9
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting python-socketio==5.11.2
#   Downloading python_socketio-5.11.2-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 KB 11.8 MB/s eta 0:00:00
# Collecting PyYAML==6.0
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 KB 55.8 MB/s eta 0:00:00
# Collecting readme_renderer==43.0
#   Downloading readme_renderer-43.0-py3-none-any.whl (13 kB)
# Collecting realtime==1.0.4
#   Downloading realtime-1.0.4-py3-none-any.whl (8.9 kB)
# Collecting redis==5.0.4
#   Downloading redis-5.0.4-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.0/252.0 KB 35.5 MB/s eta 0:00:00
# Collecting reflex==0.4.9
#   Downloading reflex-0.4.9-py3-none-any.whl (780 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.5/780.5 KB 64.3 MB/s eta 0:00:00
# Collecting reflex-calendar==0.0.4
#   Downloading reflex_calendar-0.0.4-py3-none-any.whl (5.8 kB)
# Collecting reflex-hosting-cli==0.1.13
#   Downloading reflex_hosting_cli-0.1.13-py3-none-any.whl (32 kB)
# Collecting regex==2024.4.16
#   Downloading regex-2024.4.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.0/774.0 KB 63.2 MB/s eta 0:00:00
# Collecting requests==2.31.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 KB 10.2 MB/s eta 0:00:00
# Collecting requests-oauthlib==2.0.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting requests-toolbelt==1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 8.0 MB/s eta 0:00:00
# Collecting rfc3986==2.0.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting rich==13.7.1
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 KB 29.7 MB/s eta 0:00:00
# Collecting rsa==4.9
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting safetensors==0.4.3
#   Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.8 MB/s eta 0:00:00
# Collecting scikit-learn==1.2.2
#   Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 100.4 MB/s eta 0:00:00
# Collecting scipy==1.13.0
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 34.7 MB/s eta 0:00:00
# Collecting SecretStorage==3.3.3
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting sentence-transformers==2.7.0
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 KB 26.0 MB/s eta 0:00:00
# Collecting shellingham==1.5.4
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting simple-websocket==1.0.0
#   Downloading simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Collecting six==1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting sniffio==1.3.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting SQLAlchemy==2.0.30
#   Downloading SQLAlchemy-2.0.30-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.7 MB/s eta 0:00:00
# Collecting sqlmodel==0.0.18
#   Downloading sqlmodel-0.0.18-py3-none-any.whl (26 kB)
# Collecting starlette==0.37.2
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 KB 11.8 MB/s eta 0:00:00
# Collecting starlette-admin==0.13.2
#   Downloading starlette_admin-0.13.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 90.1 MB/s eta 0:00:00
# Collecting storage3==0.7.4
#   Downloading storage3-0.7.4-py3-none-any.whl (15 kB)
# Collecting StrEnum==0.4.15
#   Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Collecting supabase==2.4.3
#   Downloading supabase-2.4.3-py3-none-any.whl (15 kB)
# Collecting supafunc==0.4.5
#   Downloading supafunc-0.4.5-py3-none-any.whl (6.1 kB)
# Collecting sympy==1.12
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 71.4 MB/s eta 0:00:00
# Collecting tabulate==0.9.0
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting tensorboard==2.15.2
#   Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 67.4 MB/s eta 0:00:00
# Collecting tensorboard-data-server==0.7.2
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 62.9 MB/s eta 0:00:00
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.3 MB/s eta 0:00:00
# Collecting tensorflow-estimator==2.15.0
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 KB 33.8 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem==0.37.0
#   Downloading tensorflow_io_gcs_filesystem-0.37.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 61.4 MB/s eta 0:00:00
# Collecting termcolor==2.4.0
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Collecting threadpoolctl==3.5.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting tokenizers==0.19.1
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 65.1 MB/s eta 0:00:00
# Collecting tomli==2.0.1
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting tomlkit==0.12.4
#   Downloading tomlkit-0.12.4-py3-none-any.whl (37 kB)
# Collecting torch==2.2.2
#   Downloading torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.0 MB/s eta 0:00:00
# Collecting torchaudio==2.2.2
#   Downloading torchaudio-2.2.2-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 88.9 MB/s eta 0:00:00
# Collecting torchvision==0.17.2
#   Downloading torchvision-0.17.2-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 100.3 MB/s eta 0:00:00
# Collecting tqdm==4.66.4
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 KB 12.0 MB/s eta 0:00:00
# Collecting transformers==4.40.1
#   Downloading transformers-4.40.1-py3-none-any.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 99.4 MB/s eta 0:00:00
# Collecting triton==2.2.0
#   Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 7.0 MB/s eta 0:00:00
# Collecting twine==5.0.0
#   Downloading twine-5.0.0-py3-none-any.whl (37 kB)
# Collecting typer==0.12.3
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 KB 7.9 MB/s eta 0:00:00
# Collecting typing_extensions==4.11.0
#   Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Collecting urllib3==2.2.1
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 19.6 MB/s eta 0:00:00
# Collecting uvicorn==0.20.0
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 9.3 MB/s eta 0:00:00
# Collecting watchdog==4.0.0
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 KB 12.9 MB/s eta 0:00:00
# Collecting watchfiles==0.21.0
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.9 MB/s eta 0:00:00
# Collecting websockets==12.0
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 KB 19.9 MB/s eta 0:00:00
# Collecting Werkzeug==3.0.3
#   Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 KB 32.0 MB/s eta 0:00:00
# Collecting wrapt==1.14.1
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 8.9 MB/s eta 0:00:00
# Collecting wsproto==1.2.0
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting zipp==3.18.1
#   Downloading zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# Collecting pip>=23.1.2
#   Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 70.2 MB/s eta 0:00:00
# Collecting setuptools<70.0,>=69.1.1
#   Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# Installing collected packages: StrEnum, nh3, mpmath, libclang, flatbuffers, zipp, wrapt, wheel, websockets, watchdog, urllib3, typing_extensions, tqdm, tomlkit, tomli, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, tabulate, sympy, sniffio, six, shellingham, setuptools, safetensors, rfc3986, regex, PyYAML, python-multipart, python-dotenv, pyproject_hooks, PyJWT, Pygments, pycparser, pyasn1, psutil, protobuf, platformdirs, pkginfo, pip, pillow, packaging, oauthlib, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, more-itertools, mdurl, MarkupSafe, Markdown, lxml, keras, joblib, jeepney, install-jdk, idna, h11, grpcio, greenlet, gast, fsspec, filelock, exceptiongroup, docutils, distro, dill, click, charset-normalizer, certifi, cachetools, bidict, bcrypt, backports.tarfile, async-timeout, annotated-types, absl-py, wsproto, Werkzeug, uvicorn, triton, SQLAlchemy, scipy, rsa, requests, redis, readme_renderer, python-dateutil, pydantic_core, pyasn1_modules, pipdeptree, opt-einsum, nvidia-cusparse-cu12, nvidia-cudnn-cu12, ml-dtypes, markdown-it-py, Mako, JPype1, Jinja2, jaraco.functools, jaraco.context, jaraco.classes, importlib_metadata, httpcore, h5py, gunicorn, google-pasta, deprecation, cffi, build, astunparse, anyio, watchfiles, starlette, simple-websocket, scikit-learn, rich, requests-toolbelt, requests-oauthlib, realtime, pydantic, nvidia-cusolver-cu12, konlpy, huggingface-hub, httpx, google-auth, cryptography, alembic, typer, torch, tokenizers, supafunc, storage3, starlette-admin, sqlmodel, SecretStorage, python-engineio, postgrest, openai, gotrue, google-auth-oauthlib, fastapi, transformers, torchvision, torchaudio, tensorboard, supabase, reflex-hosting-cli, python-socketio, keyring, twine, tensorflow, sentence-transformers, reflex, reflex-calendar
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.6.0
#     Uninstalling setuptools-59.6.0:
#       Successfully uninstalled setuptools-59.6.0
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
# Successfully installed JPype1-1.5.0 Jinja2-3.1.4 Mako-1.3.3 Markdown-3.6 MarkupSafe-2.1.5 PyJWT-2.8.0 PyYAML-6.0 Pygments-2.18.0 SQLAlchemy-2.0.30 SecretStorage-3.3.3 StrEnum-0.4.15 Werkzeug-3.0.3 absl-py-2.1.0 alembic-1.13.1 annotated-types-0.6.0 anyio-4.3.0 astunparse-1.6.3 async-timeout-4.0.3 backports.tarfile-1.1.1 bcrypt-4.1.2 bidict-0.23.1 build-1.2.1 cachetools-5.3.3 certifi-2024.2.2 cffi-1.16.0 charset-normalizer-3.3.2 click-8.1.7 cryptography-42.0.7 deprecation-2.1.0 dill-0.3.8 distro-1.9.0 docutils-0.21.2 exceptiongroup-1.2.1 fastapi-0.110.3 filelock-3.14.0 flatbuffers-24.3.25 fsspec-2024.3.1 gast-0.5.4 google-auth-2.29.0 google-auth-oauthlib-1.2.0 google-pasta-0.2.0 gotrue-2.4.2 greenlet-3.0.3 grpcio-1.63.0 gunicorn-21.2.0 h11-0.14.0 h5py-3.11.0 httpcore-1.0.5 httpx-0.27.0 huggingface-hub-0.23.0 idna-3.7 importlib_metadata-7.1.0 install-jdk-1.1.0 jaraco.classes-3.4.0 jaraco.context-5.3.0 jaraco.functools-4.0.1 jeepney-0.8.0 joblib-1.4.2 keras-2.15.0 keyring-25.2.0 konlpy-0.6.0 libclang-18.1.1 lxml-5.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.2.0 more-itertools-10.2.0 mpmath-1.3.0 networkx-3.3 nh3-0.2.17 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 oauthlib-3.2.2 openai-1.20.0 opt-einsum-3.3.0 packaging-24.0 pillow-10.3.0 pip-24.0 pipdeptree-2.16.2 pkginfo-1.10.0 platformdirs-4.2.1 postgrest-0.16.4 protobuf-4.25.3 psutil-5.9.8 pyasn1-0.6.0 pyasn1_modules-0.4.0 pycparser-2.22 pydantic-2.7.1 pydantic_core-2.18.2 pyproject_hooks-1.1.0 python-dateutil-2.9.0.post0 python-dotenv-1.0.1 python-engineio-4.9.0 python-multipart-0.0.9 python-socketio-5.11.2 readme_renderer-43.0 realtime-1.0.4 redis-5.0.4 reflex-0.4.9 reflex-calendar-0.0.4 reflex-hosting-cli-0.1.13 regex-2024.4.16 requests-2.31.0 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 rfc3986-2.0.0 rich-13.7.1 rsa-4.9 safetensors-0.4.3 scikit-learn-1.2.2 scipy-1.13.0 sentence-transformers-2.7.0 setuptools-69.5.1 shellingham-1.5.4 simple-websocket-1.0.0 six-1.16.0 sniffio-1.3.1 sqlmodel-0.0.18 starlette-0.37.2 starlette-admin-0.13.2 storage3-0.7.4 supabase-2.4.3 supafunc-0.4.5 sympy-1.12 tabulate-0.9.0 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-io-gcs-filesystem-0.37.0 termcolor-2.4.0 threadpoolctl-3.5.0 tokenizers-0.19.1 tomli-2.0.1 tomlkit-0.12.4 torch-2.2.2 torchaudio-2.2.2 torchvision-0.17.2 tqdm-4.66.4 transformers-4.40.1 triton-2.2.0 twine-5.0.0 typer-0.12.3 typing_extensions-4.11.0 urllib3-2.2.1 uvicorn-0.20.0 watchdog-4.0.0 watchfiles-0.21.0 websockets-12.0 wheel-0.43.0 wrapt-1.14.1 wsproto-1.2.0 zipp-3.18.1

# %%
# !./deploy/build.sh
# Out:
# ───────────────────────────────────────── Initializing app ─────────────────────────────────────────
# [00:12:26] Prior to reflex 0.4.0, rx.* components are based on Chakra UI. They are now ]8;id=503490;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=146667;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#            based on Radix UI. To stick to Chakra UI, use rx.chakra.*.
#                                                                                        ]8;id=603882;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=847973;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#            Run `reflex script keep-chakra` to automatically update your app.           ]8;id=180766;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=484971;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#                                                                                        ]8;id=496200;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=779345;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#            For more details, please see                                                ]8;id=740170;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=333120;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
#            https://reflex.dev/blog/2024-02-16-reflex-v0.4.0/
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
# ⠏ Installing node Installing Node v18.17.0 (x64)
# ⠋ Installing node Installing Node v18.17.0 (x64)
# ⠙ Installing node Installing Node v18.17.0 (x64)
# ⠹ Installing node Installing Node v18.17.0 (x64)
# ⠸ Installing node Installing Node v18.17.0 (x64)
# ⠼ Installing node Installing Node v18.17.0 (x64)
# ⠴ Installing node Installing Node v18.17.0 (x64)
# ⠦ Installing node Installing Node v18.17.0 (x64)
# ⠧ Installing node Installing Node v18.17.0 (x64)
# ⠇ Installing node Installing Node v18.17.0 (x64)
#
# [00:12:33] Initializing the web directory.                                             ]8;id=836383;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py\console.py]8;;\:]8;id=47294;file:///content/iNotePal/app/.venv/lib/python3.10/site-packages/reflex/utils/console.py#95\95]8;;\
# Success: Initialized app
# ──────────────────────── Compiling production app and preparing for export. ────────────────────────
# JAVA INSTALLED: /content/iNotePal/app/.cache/jdk/jdk-22.0.1+8
# Compiling: ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 19/19 0:00:02
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠏ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolving dependencies
# ⠹ Installing base frontend packages  Resolving dependencies
# ⠸ Installing base frontend packages  Resolving dependencies
# ⠼ Installing base frontend packages  Resolving dependencies
# ⠴ Installing base frontend packages  Resolving dependencies
# ⠦ Installing base frontend packages  Resolving dependencies
# ⠧ Installing base frontend packages  Resolving dependencies
# ⠇ Installing base frontend packages  Resolving dependencies
# ⠋ Installing base frontend packages  Resolving dependencies
# ⠙ Installing base frontend packages  Resolved, downloaded and extracted [570]
# ⠹ Installing base frontend packages  Resolved, downloaded and extracted [570]
# ⠸ Installing base frontend packages  Resolved, downloaded and extracted [570]
# ⠼ Installing base frontend packages  140 packages installed [4.37s]
# ⠼ Installing base frontend packages  140 packages installed [4.37s]
#
# ⠋ Installing tailwind  Resolving dependencies
# ⠙ Installing tailwind  Resolving dependencies
# ⠹ Installing tailwind  Resolving dependencies
# ⠸ Installing tailwind  Resolving dependencies
# ⠼ Installing tailwind  Resolving dependencies
# ⠴ Installing tailwind  Resolving dependencies
# ⠦ Installing tailwind  Resolving dependencies
# ⠧ Installing tailwind  Resolving dependencies
# ⠇ Installing tailwind  Resolving dependencies
# ⠏ Installing tailwind  Resolving dependencies
# ⠋ Installing tailwind  Resolving dependencies
# ⠙ Installing tailwind  Resolving dependencies
# ⠹ Installing tailwind  Resolved, downloaded and extracted [274]
# ⠸ Installing tailwind  79 packages installed [1107.00ms]
#
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components  Resolving dependencies
# ⠹ Installing frontend packages from config and components  Resolving dependencies
# ⠸ Installing frontend packages from config and components  Resolving dependencies
# ⠼ Installing frontend packages from config and components  Resolving dependencies
# ⠴ Installing frontend packages from config and components  Resolving dependencies
# ⠦ Installing frontend packages from config and components  Resolving dependencies
# ⠧ Installing frontend packages from config and components  Resolving dependencies
# ⠇ Installing frontend packages from config and components  Resolving dependencies
# ⠏ Installing frontend packages from config and components  Resolving dependencies
# ⠋ Installing frontend packages from config and components  Resolving dependencies
# ⠙ Installing frontend packages from config and components warn: incorrect peer dependency
# "react@18.2.0"
# ⠹ Installing frontend packages from config and components warn: incorrect peer dependency
# "react@18.2.0"
# ⠸ Installing frontend packages from config and components warn: incorrect peer dependency
# "react@18.2.0"
# ⠼ Installing frontend packages from config and components  222 packages installed [4.43s]
#
# Creating Production Build:  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 9/9 0:01:14
# Zipping Frontend: ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 40/40 0:00:00
# Zipping Backend: ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 39/39 0:00:00

# %%
# !ls -al | grep .zip
# Out:
# -rw-r--r--  1 root root  33462 May 10 00:14 backend.zip
# -rw-r--r--  1 root root 670657 May 10 00:14 frontend.zip

# %%
commit_hash = !git log -1 --pretty=format:'%H'
release_options = " ".join([
    version,
    f"--target {commit_hash[0]}",
    "--prerelease" if is_prerelease else "",
])
release_options
# Out:
# 'reflex-0.1.7 --target e7b6abe1e7260d977012fd2b842ef874f317cd8e '

# %%
# !gh release create {release_options} --generate-notes /content/iNotePal/app/*.zip
# Out:
# https://github.com/pal-ette/iNotePal/releases/tag/reflex-0.1.7
